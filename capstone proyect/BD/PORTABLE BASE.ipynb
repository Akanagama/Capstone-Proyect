-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
USE [KialChickenDB]
GO

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 13/06/2026 12:18:57 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[ClienteID] [int] IDENTITY(1,1) NOT NULL,
	[TipoDocumento] [varchar](20) NULL,
	[NumeroDocumento] [varchar](20) NOT NULL,
	[NombreCompleto] [varchar](150) NOT NULL,
	[Direccion] [varchar](200) NULL,
	[Telefono] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ClienteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetalleVentas]

-- %%
/****** Object:  Table [dbo].[DetalleVentas]    Script Date: 13/06/2026 12:18:57 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetalleVentas](
	[DetalleID] [int] IDENTITY(1,1) NOT NULL,
	[VentaID] [int] NULL,
	[PlatoID] [int] NULL,
	[Cantidad] [int] NOT NULL,
	[PrecioUnitario] [decimal](10, 2) NOT NULL,
	[SubTotal] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[DetalleID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Insumos]

-- %%
/****** Object:  Table [dbo].[Insumos]    Script Date: 13/06/2026 12:18:57 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Insumos](
	[InsumoID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](100) NOT NULL,
	[UnidadMedida] [varchar](20) NOT NULL,
	[StockActual] [decimal](10, 2) NOT NULL,
	[StockMinimo] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[InsumoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Platos]

-- %%
/****** Object:  Table [dbo].[Platos]    Script Date: 13/06/2026 12:18:57 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Platos](
	[PlatoID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](100) NOT NULL,
	[Categoria] [varchar](50) NOT NULL,
	[Precio] [decimal](10, 2) NOT NULL,
	[Estado] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[PlatoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 13/06/2026 12:18:57 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[UsuarioID] [int] IDENTITY(1,1) NOT NULL,
	[NombreCompleto] [varchar](100) NOT NULL,
	[Username] [varchar](50) NOT NULL,
	[Password] [varchar](50) NOT NULL,
	[Rol] [varchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UsuarioID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ventas]

-- %%
/****** Object:  Table [dbo].[Ventas]    Script Date: 13/06/2026 12:18:57 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ventas](
	[VentaID] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [varchar](50) NULL,
	[UsuarioID] [int] NULL,
	[ClienteID] [int] NULL,
	[MetodoPago] [varchar](50) NOT NULL,
	[SubTotal] [decimal](10, 2) NOT NULL,
	[IGV] [decimal](10, 2) NOT NULL,
	[Total] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[VentaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
SET IDENTITY_INSERT [dbo].[Clientes] ON 
INSERT [dbo].[Clientes] ([ClienteID], [TipoDocumento], [NumeroDocumento], [NombreCompleto], [Direccion], [Telefono]) VALUES (1, N'DNI', N'00000000', N'Público General', N'Puerto Malabrigo', NULL)
INSERT [dbo].[Clientes] ([ClienteID], [TipoDocumento], [NumeroDocumento], [NombreCompleto], [Direccion], [Telefono]) VALUES (4, N'DNI', N'71324742', N'Arturo Michael Bravo Medina', N'A.v ejercito 1194', NULL)
INSERT [dbo].[Clientes] ([ClienteID], [TipoDocumento], [NumeroDocumento], [NombreCompleto], [Direccion], [Telefono]) VALUES (8, N'DNI', N'73176614', N'Rufo Eduardo Lujan Alayo', N'Ovalo papal', NULL)
SET IDENTITY_INSERT [dbo].[Clientes] OFF
GO

-- %% [markdown]
-- # [dbo].[DetalleVentas]

-- %%
SET IDENTITY_INSERT [dbo].[DetalleVentas] ON 
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (1, 1, 4, 1, CAST(12.00 AS Decimal(10, 2)), CAST(12.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (2, 1, 5, 1, CAST(10.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (3, 1, 6, 1, CAST(98.00 AS Decimal(10, 2)), CAST(98.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (4, 2, 1, 1, CAST(18.00 AS Decimal(10, 2)), CAST(18.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (5, 2, 4, 1, CAST(12.00 AS Decimal(10, 2)), CAST(12.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (6, 2, 5, 1, CAST(10.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (7, 3, 6, 1, CAST(98.00 AS Decimal(10, 2)), CAST(98.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (8, 3, 5, 1, CAST(10.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (9, 4, 5, 1, CAST(10.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (10, 4, 6, 2, CAST(98.00 AS Decimal(10, 2)), CAST(196.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (11, 4, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (12, 5, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (13, 6, 3, 1, CAST(65.00 AS Decimal(10, 2)), CAST(65.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (14, 8, 4, 1, CAST(12.00 AS Decimal(10, 2)), CAST(12.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (15, 8, 5, 1, CAST(10.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (16, 8, 6, 1, CAST(98.00 AS Decimal(10, 2)), CAST(98.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (17, 9, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (18, 9, 7, 3, CAST(14.00 AS Decimal(10, 2)), CAST(42.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (19, 10, 1, 1, CAST(18.00 AS Decimal(10, 2)), CAST(18.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (20, 10, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (21, 11, 1, 3, CAST(18.00 AS Decimal(10, 2)), CAST(54.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (22, 11, 5, 2, CAST(10.00 AS Decimal(10, 2)), CAST(20.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (23, 12, 5, 2, CAST(10.00 AS Decimal(10, 2)), CAST(20.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (24, 12, 6, 1, CAST(98.00 AS Decimal(10, 2)), CAST(98.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (25, 12, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (26, 13, 3, 1, CAST(65.00 AS Decimal(10, 2)), CAST(65.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (27, 13, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (28, 13, 7, 1, CAST(14.00 AS Decimal(10, 2)), CAST(14.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (29, 14, 8, 5, CAST(24.00 AS Decimal(10, 2)), CAST(120.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (30, 15, 8, 1, CAST(24.00 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (31, 15, 7, 2, CAST(14.00 AS Decimal(10, 2)), CAST(28.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (32, 16, 5, 3, CAST(10.00 AS Decimal(10, 2)), CAST(30.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (33, 16, 1, 1, CAST(18.00 AS Decimal(10, 2)), CAST(18.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (34, 16, 2, 1, CAST(32.00 AS Decimal(10, 2)), CAST(32.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (35, 17, 6, 1, CAST(98.00 AS Decimal(10, 2)), CAST(98.00 AS Decimal(10, 2)))
INSERT [dbo].[DetalleVentas] ([DetalleID], [VentaID], [PlatoID], [Cantidad], [PrecioUnitario], [SubTotal]) VALUES (36, 17, 7, 1, CAST(14.00 AS Decimal(10, 2)), CAST(14.00 AS Decimal(10, 2)))
SET IDENTITY_INSERT [dbo].[DetalleVentas] OFF
GO

-- %% [markdown]
-- # [dbo].[Insumos]

-- %%
SET IDENTITY_INSERT [dbo].[Insumos] ON 
INSERT [dbo].[Insumos] ([InsumoID], [Nombre], [UnidadMedida], [StockActual], [StockMinimo]) VALUES (1, N'Pollos Enteros Macerados', N'Unidades', CAST(2.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[Insumos] ([InsumoID], [Nombre], [UnidadMedida], [StockActual], [StockMinimo]) VALUES (2, N'Papas Amarillas', N'Sacos 50kg', CAST(2.00 AS Decimal(10, 2)), CAST(5.00 AS Decimal(10, 2)))
INSERT [dbo].[Insumos] ([InsumoID], [Nombre], [UnidadMedida], [StockActual], [StockMinimo]) VALUES (3, N'Aceite Vegetal', N'Bidones 20L', CAST(30.00 AS Decimal(10, 2)), CAST(4.00 AS Decimal(10, 2)))
INSERT [dbo].[Insumos] ([InsumoID], [Nombre], [UnidadMedida], [StockActual], [StockMinimo]) VALUES (4, N'Pepinillos', N'Kilogramos', CAST(2.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(10, 2)))
INSERT [dbo].[Insumos] ([InsumoID], [Nombre], [UnidadMedida], [StockActual], [StockMinimo]) VALUES (5, N'Tomate', N'Kilogramos', CAST(15.00 AS Decimal(10, 2)), CAST(6.00 AS Decimal(10, 2)))
INSERT [dbo].[Insumos] ([InsumoID], [Nombre], [UnidadMedida], [StockActual], [StockMinimo]) VALUES (7, N'Lechuga', N'Kilogramos', CAST(20.00 AS Decimal(10, 2)), CAST(5.00 AS Decimal(10, 2)))
SET IDENTITY_INSERT [dbo].[Insumos] OFF
GO

-- %% [markdown]
-- # [dbo].[Platos]

-- %%
SET IDENTITY_INSERT [dbo].[Platos] ON 
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (1, N'1/4 de Pollo', N'Pollos a la Brasa', CAST(18.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (2, N'1/2 Pollo', N'Pollos a la Brasa', CAST(32.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (3, N'Pollo Entero', N'Pollos a la Brasa', CAST(65.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (4, N'Chicha 1L', N'Bebidas', CAST(12.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (5, N'Porción Papas', N'Guarniciones', CAST(10.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (6, N'PARILLA FAMILIAR', N'Parrillas', CAST(98.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (7, N'Limonada 1L', N'Bebidas', CAST(14.00 AS Decimal(10, 2)), N'Activo')
INSERT [dbo].[Platos] ([PlatoID], [Nombre], [Categoria], [Precio], [Estado]) VALUES (8, N'Parrilla Junior', N'Parrillas', CAST(24.00 AS Decimal(10, 2)), N'Activo')
SET IDENTITY_INSERT [dbo].[Platos] OFF
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
SET IDENTITY_INSERT [dbo].[Usuarios] ON 
INSERT [dbo].[Usuarios] ([UsuarioID], [NombreCompleto], [Username], [Password], [Rol]) VALUES (1, N'Arturo Medina', N'admin', N'123', N'admin')
INSERT [dbo].[Usuarios] ([UsuarioID], [NombreCompleto], [Username], [Password], [Rol]) VALUES (2, N'Arturo Bravo', N'arturo', N'123', N'cajero')
INSERT [dbo].[Usuarios] ([UsuarioID], [NombreCompleto], [Username], [Password], [Rol]) VALUES (3, N'Jesus Cardoza', N'jesus', N'123', N'cajero')
INSERT [dbo].[Usuarios] ([UsuarioID], [NombreCompleto], [Username], [Password], [Rol]) VALUES (4, N'Rufo Lujan', N'Ñufales', N'123', N'admin')
INSERT [dbo].[Usuarios] ([UsuarioID], [NombreCompleto], [Username], [Password], [Rol]) VALUES (5, N'Anderson', N'anderson', N'123', N'cajero')
SET IDENTITY_INSERT [dbo].[Usuarios] OFF
GO

-- %% [markdown]
-- # [dbo].[Ventas]

-- %%
SET IDENTITY_INSERT [dbo].[Ventas] ON 
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (1, N'May 30 2026  3:26AM', 1, NULL, N'Efectivo', CAST(98.40 AS Decimal(10, 2)), CAST(21.60 AS Decimal(10, 2)), CAST(120.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (2, N'May 30 2026  4:15AM', 1, NULL, N'Efectivo', CAST(32.80 AS Decimal(10, 2)), CAST(7.20 AS Decimal(10, 2)), CAST(40.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (3, N'May 30 2026  8:10AM', 1, 4, N'Efectivo', CAST(88.56 AS Decimal(10, 2)), CAST(19.44 AS Decimal(10, 2)), CAST(108.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (4, N'May 30 2026  8:15AM', 1, 4, N'Yape/Plin', CAST(188.60 AS Decimal(10, 2)), CAST(41.40 AS Decimal(10, 2)), CAST(230.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (5, N'May 30 2026  8:19AM', 1, NULL, N'Tarjeta', CAST(19.68 AS Decimal(10, 2)), CAST(4.32 AS Decimal(10, 2)), CAST(24.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (6, N'May 30 2026  8:20AM', 1, NULL, N'Efectivo', CAST(53.30 AS Decimal(10, 2)), CAST(11.70 AS Decimal(10, 2)), CAST(65.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (8, N'May 30 2026  8:40AM', 1, 1, N'Efectivo', CAST(98.40 AS Decimal(10, 2)), CAST(21.60 AS Decimal(10, 2)), CAST(120.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (9, N'May 30 2026  9:16AM', 1, 4, N'Yape/Plin', CAST(54.12 AS Decimal(10, 2)), CAST(11.88 AS Decimal(10, 2)), CAST(66.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (10, N'May 30 2026  9:18AM', 1, 1, N'Tarjeta', CAST(34.44 AS Decimal(10, 2)), CAST(7.56 AS Decimal(10, 2)), CAST(42.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (11, N'May 30 2026 10:12AM', 1, 4, N'Tarjeta', CAST(60.68 AS Decimal(10, 2)), CAST(13.32 AS Decimal(10, 2)), CAST(74.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (12, N'Jun  1 2026  9:58PM', 1, 4, N'Yape/Plin', CAST(116.44 AS Decimal(10, 2)), CAST(25.56 AS Decimal(10, 2)), CAST(142.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (13, N'Jun  7 2026 12:22AM', 1, 8, N'Tarjeta', CAST(84.46 AS Decimal(10, 2)), CAST(18.54 AS Decimal(10, 2)), CAST(103.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (14, N'Jun  7 2026 12:35AM', 1, 1, N'Yape/Plin', CAST(98.40 AS Decimal(10, 2)), CAST(21.60 AS Decimal(10, 2)), CAST(120.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (15, N'Jun 12 2026  6:07PM', 1, 4, N'Tarjeta', CAST(42.64 AS Decimal(10, 2)), CAST(9.36 AS Decimal(10, 2)), CAST(52.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (16, N'Jun 12 2026  6:12PM', 1, 1, N'Yape/Plin', CAST(65.60 AS Decimal(10, 2)), CAST(14.40 AS Decimal(10, 2)), CAST(80.00 AS Decimal(10, 2)))
INSERT [dbo].[Ventas] ([VentaID], [Fecha], [UsuarioID], [ClienteID], [MetodoPago], [SubTotal], [IGV], [Total]) VALUES (17, N'Jun 12 2026  8:08PM', 1, 8, N'Yape/Plin', CAST(91.84 AS Decimal(10, 2)), CAST(20.16 AS Decimal(10, 2)), CAST(112.00 AS Decimal(10, 2)))
SET IDENTITY_INSERT [dbo].[Ventas] OFF
GO

-- %% [markdown]
-- # [UQ__Clientes__A420258856A88C7E]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Clientes__A420258856A88C7E]    Script Date: 13/06/2026 12:18:57 a. m. ******/
ALTER TABLE [dbo].[Clientes] ADD UNIQUE NONCLUSTERED 
(
	[NumeroDocumento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__Usuarios__536C85E4A8D2A55A]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Usuarios__536C85E4A8D2A55A]    Script Date: 13/06/2026 12:18:57 a. m. ******/
ALTER TABLE [dbo].[Usuarios] ADD UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Platos__Estado__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Platos] ADD  DEFAULT ('Activo') FOR [Estado]
GO

-- %% [markdown]
-- # [DF__Ventas__Fecha__4222D4EF]

-- %%
ALTER TABLE [dbo].[Ventas] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [FK__DetalleVe__Plato__47DBAE45]

-- %%
ALTER TABLE [dbo].[DetalleVentas]  WITH CHECK ADD FOREIGN KEY([PlatoID])
REFERENCES [dbo].[Platos] ([PlatoID])
GO

-- %% [markdown]
-- # [FK__DetalleVe__Venta__46E78A0C]

-- %%
ALTER TABLE [dbo].[DetalleVentas]  WITH CHECK ADD FOREIGN KEY([VentaID])
REFERENCES [dbo].[Ventas] ([VentaID])
GO

-- %% [markdown]
-- # [FK__Ventas__ClienteI__440B1D61]

-- %%
ALTER TABLE [dbo].[Ventas]  WITH CHECK ADD FOREIGN KEY([ClienteID])
REFERENCES [dbo].[Clientes] ([ClienteID])
GO

-- %% [markdown]
-- # [FK__Ventas__UsuarioI__4316F928]

-- %%
ALTER TABLE [dbo].[Ventas]  WITH CHECK ADD FOREIGN KEY([UsuarioID])
REFERENCES [dbo].[Usuarios] ([UsuarioID])
GO
